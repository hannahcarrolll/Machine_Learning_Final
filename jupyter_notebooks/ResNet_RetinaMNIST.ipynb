# %% [markdown]
# ## ResNet

# %%
# installs
# !pip install monai # model
# !pip install medmnist # data
# Out:
# Collecting monai
#   Downloading monai-1.4.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: numpy<2.0,>=1.24 in /usr/local/lib/python3.10/dist-packages (from monai) (1.26.4)
# Requirement already satisfied: torch>=1.9 in /usr/local/lib/python3.10/dist-packages (from monai) (2.5.1+cu121)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.9->monai) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.9->monai) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.9->monai) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.9->monai) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.9->monai) (2024.10.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.9->monai) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch>=1.9->monai) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.9->monai) (3.0.2)
# Downloading monai-1.4.0-py3-none-any.whl (1.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 16.2 MB/s eta 0:00:00
# Installing collected packages: monai
# Successfully installed monai-1.4.0
# Collecting medmnist
#   Downloading medmnist-3.0.2-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from medmnist) (1.26.4)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from medmnist) (2.2.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from medmnist) (1.5.2)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.10/dist-packages (from medmnist) (0.24.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from medmnist) (4.66.6)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from medmnist) (11.0.0)
# Collecting fire (from medmnist)
#   Downloading fire-0.7.0.tar.gz (87 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.2/87.2 kB 2.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from medmnist) (2.5.1+cu121)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from medmnist) (0.20.1+cu121)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.10/dist-packages (from fire->medmnist) (2.5.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->medmnist) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->medmnist) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->medmnist) (2024.2)
# Requirement already satisfied: scipy>=1.9 in /usr/local/lib/python3.10/dist-packages (from scikit-image->medmnist) (1.13.1)
# Requirement already satisfied: networkx>=2.8 in /usr/local/lib/python3.10/dist-packages (from scikit-image->medmnist) (3.4.2)
# Requirement already satisfied: imageio>=2.33 in /usr/local/lib/python3.10/dist-packages (from scikit-image->medmnist) (2.36.0)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.10/dist-packages (from scikit-image->medmnist) (2024.9.20)
# Requirement already satisfied: packaging>=21 in /usr/local/lib/python3.10/dist-packages (from scikit-image->medmnist) (24.2)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.10/dist-packages (from scikit-image->medmnist) (0.4)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->medmnist) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->medmnist) (3.5.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch->medmnist) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch->medmnist) (4.12.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->medmnist) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch->medmnist) (2024.10.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch->medmnist) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch->medmnist) (1.3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->medmnist) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->medmnist) (3.0.2)
# Downloading medmnist-3.0.2-py3-none-any.whl (25 kB)
# Building wheels for collected packages: fire
#   Building wheel for fire (setup.py) ... done
#   Created wheel for fire: filename=fire-0.7.0-py3-none-any.whl size=114249 sha256=75f612500c61825dc3881353f84c8a9ee7e928dab0ea0c88bfa0947779616078
#   Stored in directory: /root/.cache/pip/wheels/19/39/2f/2d3cadc408a8804103f1c34ddd4b9f6a93497b11fa96fe738e
# Successfully built fire
# Installing collected packages: fire, medmnist
# Successfully installed fire-0.7.0 medmnist-3.0.2

# %%
# imports
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import matplotlib.pyplot as plt
from medmnist import RetinaMNIST
from torch.utils.data import DataLoader, random_split
from torchvision.transforms import Compose, ToTensor, Normalize
from monai.networks.blocks import MLPBlock
from torchvision import models, transforms
from monai.networks.nets import ResNet

import monai
from monai.apps import download_and_extract
from monai.data import CacheDataset, DataLoader, pad_list_data_collate, partition_dataset
from monai.networks import eval_mode
import monai.transforms as mt
from monai.utils import set_determinism

from sklearn.metrics import confusion_matrix
import seaborn as sns

# %% [markdown]
# ## Load Data Set

# %%
# load RetinaMNIST dataset
def get_retina_mnist_data(split, transform=None):
    return RetinaMNIST(split=split, transform=transform, download=True, as_rgb=True)

# preprocessing transformation for the RetinaMNIST images
transform = transforms.Compose([
    transforms.Resize(256),  # resize the image to at least 256 pixels in the smaller dimension
    transforms.CenterCrop(224),  # crop the center of the image to 224x224 pixels (required by ResNet)
    transforms.ToTensor(),  # convert the image to a PyTorch tensor (values scaled to [0, 1])
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])  # normalize using ImageNet stats
])

# load train and validation splits
train_dataset = get_retina_mnist_data("train", transform)
val_dataset = get_retina_mnist_data("val", transform)
# Out:
# Downloading https://zenodo.org/records/10519652/files/retinamnist.npz?download=1 to /root/.medmnist/retinamnist.npz
# 100%|██████████| 3.29M/3.29M [00:03<00:00, 926kB/s]
# Using downloaded and verified file: /root/.medmnist/retinamnist.npz

# %% [markdown]
# ## Dataloaders

# %%
# define batch size
batch_size = 32
# create dataloaders
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)

# %% [markdown]
# ## Define Model

# %%
class ResNetModel(nn.Module):
    def __init__(self, num_classes):
        super(ResNetModel, self).__init__()
        self.resnet = models.resnet18(pretrained=True)  # You can choose resnet50, resnet34, etc.

        # Modify the final fully connected layer for your number of classes
        self.resnet.fc = nn.Linear(self.resnet.fc.in_features, num_classes)

    def forward(self, x):
        return self.resnet(x)  # Forward pass through ResNet

# Initialize model
num_classes = 5  # Number of classes for RetinaMNIST
model = ResNetModel(num_classes=num_classes)
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
# 100%|██████████| 44.7M/44.7M [00:00<00:00, 172MB/s]

# %%
# move the model to the GPU (if available)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)
# Out:
# ResNetModel(
#   (resnet): ResNet(
#     (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (layer1): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (layer2): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (layer3): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (layer4): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#     (fc): Linear(in_features=512, out_features=5, bias=True)
#   )
# )

# %%
# define the loss function and optimizer
criterion = nn.CrossEntropyLoss()  # cross-entropy loss for classification tasks
optimizer = optim.Adam(model.parameters(), lr=0.001)  # adam optimizer

# %% [markdown]
# ## Train

# %%
# Training loop
num_epochs = 200
train_acc = []
val_acc = []

for epoch in range(num_epochs):
    model.train()  # Set the model to training mode
    running_loss = 0.0
    correct = 0
    total = 0

    for inputs, labels in train_loader:
        inputs, labels = inputs.to(device), labels.squeeze().to(device)

        optimizer.zero_grad()  # Zero the gradients before each backward pass
        outputs = model(inputs)  # Forward pass
        loss = criterion(outputs, labels)  # Compute the loss
        loss.backward()  # Backpropagation
        optimizer.step()  # Update the model parameters

        running_loss += loss.item()
        _, predicted = torch.max(outputs, 1)  # Get the predicted class
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

    accuracy = 100 * correct / total  # Calculate accuracy
    train_acc.append(accuracy)
    print(f"Epoch {epoch+1}/{num_epochs}, Loss: {running_loss/len(train_loader):.4f}, Accuracy: {accuracy:.2f}%")

    # Validate the model
    model.eval()  # Set the model to evaluation mode
    correct = 0
    total = 0
    with torch.no_grad():
        for inputs, labels in val_loader:
            inputs, labels = inputs.to(device), labels.squeeze().to(device)
            outputs = model(inputs)
            _, predicted = torch.max(outputs, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

    val_accuracy = 100 * correct / total
    val_acc.append(val_accuracy)
    print(f"Validation Accuracy: {val_accuracy:.2f}%")
# Out:
# Epoch 1/200, Loss: 1.1764, Accuracy: 50.65%
# Validation Accuracy: 50.00%
# Epoch 2/200, Loss: 1.1743, Accuracy: 51.57%
# Validation Accuracy: 54.17%
# Epoch 3/200, Loss: 1.1228, Accuracy: 54.35%
# Validation Accuracy: 55.00%
# Epoch 4/200, Loss: 1.1426, Accuracy: 51.67%
# Validation Accuracy: 52.50%
# Epoch 5/200, Loss: 1.1207, Accuracy: 53.43%
# Validation Accuracy: 60.83%
# Epoch 6/200, Loss: 1.0948, Accuracy: 53.89%
# Validation Accuracy: 54.17%
# Epoch 7/200, Loss: 1.0991, Accuracy: 54.54%
# Validation Accuracy: 55.00%
Accuracy: 100.00%
# Validation Accuracy: 46.67%
# Epoch 80/200, Loss: 0.0015, Accuracy: 100.00%
# Validation Accuracy: 47.50%
# Epoch 81/200, Loss: 0.0007, Accuracy: 100.00%
# Validation Accuracy: 47.50%
# Epoch 82/200, Loss: 0.0008, Accuracy: 100.00%
# Validation Accuracy: 46.67%
# Epoch 83/200, Loss: 0.0005, Accuracy: 100.00%
# Validation Accuracy: 48.33%
# Epoch 84/200, Loss: 0.0009, Accuracy: 100.00%
# Validation Accuracy: 49.17%
# Epoch 85/200, Loss: 0.0007, Accuracy: 100.00%
# Validation Accuracy: 46.67%
# Epoch 86/200, Loss: 0.0006, Accuracy: 100.00%
# Validation Accuracy: 45.83%
# Epoch 87/200, Loss: 0.0003, Accuracy: 100.00%
# Validation Accuracy: 45.83%
# Epoch 88/200, Loss: 0.0003, Accuracy: 100.00%
# Validation Accuracy: 47.50%
# Epoch 89/200, Loss: 0.0006, Accuracy: 100.00%
# Validation Accuracy: 47.50%
# Epoch 90/200, Loss: 0.0003, Accuracy: 100.00%
# Validation Accuracy: 46.67%
# Epoch 91/200, Loss: 0.0002, Accuracy: 100.00%
# Validation Accuracy: 45.83%
# Epoch 92/200, Loss: 0.0002, Accuracy: 100.00%
# Validation Accuracy: 46.67%
# Epoch 93/200, Loss: 0.0001, Accuracy: 100.00%
# Validation Accuracy: 46.67%
# Epoch 94/200, Loss: 0.0003, Accuracy: 100.00%
# Validation Accuracy: 46.67%
# Epoch 95/200, Loss: 0.0001, Accuracy: 100.00%
# Validation Accuracy: 46.67%
# Epoch 96/200, Loss: 0.0001, Accuracy: 100.00%
# Validation Accuracy: 45.83%
# Epoch 97/200, Loss: 0.0001, Accuracy: 100.00%
# Validation Accuracy: 45.83%
# Epoch 98/200, Loss: 0.0002, Accuracy: 100.00%
# Validation Accuracy: 47.50%
# Epoch 99/200, Loss: 0.0001, Accuracy: 100.00%
# Validation Accuracy: 46.67%
# Epoch 100/200, Loss: 0.0001, Accuracy: 100.00%
# Validation Accuracy: 47.50%
# Epoch 101/200, Loss: 0.0001, Accuracy: 100.00%
# Validation Accuracy: 46.67%
# Epoch 102/200, Loss: 0.0002, Accuracy: 100.00%
# Validation Accuracy: 46.67%
# Epoch 103/200, Loss: 0.0001, Accuracy: 100.00%
# Validation Accuracy: 46.67%
# Epoch 104/200, Loss: 0.0001, Accuracy: 100.00%
# Validation Accuracy: 48.33%
# Epoch 105/200, Loss: 0.0001, Accuracy: 100.00%
# Validation Accuracy: 46.67%
# Epoch 106/200, Loss: 0.0001, Accuracy: 100.00%
# Validation Accuracy: 47.50%
# Epoch 107/200, Loss: 0.0001, Accuracy: 100.00%
# Validation Accuracy: 46.67%
# Epoch 108/200, Loss: 0.0001, Accuracy: 100.00%
# Validation Accuracy: 45.83%
# Epoch 109/200, Loss: 0.0002, Accuracy: 100.00%
# Validation Accuracy: 46.67%
# Epoch 110/200, Loss: 0.0001, Accuracy: 100.00%
# Validation Accuracy: 48.33%
# Epoch 111/200, Loss: 0.0001, Accuracy: 100.00%
# Validation Accuracy: 47.50%
# Epoch 112/200, Loss: 0.0001, Accuracy: 100.00%
# Validation Accuracy: 45.83%
# Epoch 113/200, Loss: 0.0001, Accuracy: 100.00%
# Validation Accuracy: 45.00%
# Epoch 114/200, Loss: 0.0002, Accuracy: 100.00%
# Validation Accuracy: 46.67%
# Epoch 115/200, Loss: 0.0001, Accuracy: 100.00%
# Validation Accuracy: 45.83%
# Epoch 116/200, Loss: 0.0001, Accuracy: 100.00%
# Validation Accuracy: 46.67%
# Epoch 117/200, Loss: 0.0000, Accuracy: 100.00%
# Validation Accuracy: 45.00%
# Epoch 118/200, Loss: 0.0001, Accuracy: 100.00%
# Validation Accuracy: 47.50%
# Epoch 119/200, Loss: 0.0001, Accuracy: 100.00%
# Validation Accuracy: 45.83%
# Epoch 120/200, Loss: 0.0001, Accuracy: 100.00%
# Validation Accuracy: 46.67%
# Epoch 121/200, Loss: 0.0001, Accuracy: 100.00%
# Validation Accuracy: 45.83%
# Epoch 122/200, Loss: 0.0000, Accuracy: 100.00%
# Validation Accuracy: 45.83%
# Epoch 123/200, Loss: 0.0001, Accuracy: 100.00%
# Validation Accuracy: 46.67%
# Epoch 124/200, Loss: 0.0001, Accuracy: 100.00%
# Validation Accuracy: 46.67%
# Epoch 125/200, Loss: 0.0001, Accuracy: 100.00%
# Validation Accuracy: 44.17%
# Epoch 126/200, Loss: 0.0000, Accuracy: 100.00%
# Validation Accuracy: 45.00%
# Epoch 127/200, Loss: 0.0001, Accuracy: 100.00%
# Validation Accuracy: 44.17%
# Epoch 128/200, Loss: 0.0000, Accuracy: 100.00%
# Validation Accuracy: 47.50%
# Epoch 129/200, Loss: 0.0000, Accuracy: 100.00%
# Validation Accuracy: 45.00%
# Epoch 130/200, Loss: 0.0000, Accuracy: 100.00%
# Validation Accuracy: 45.83%
# Epoch 131/200, Loss: 0.0001, Accuracy: 100.00%
# Validation Accuracy: 46.67%
# Epoch 132/200, Loss: 0.0001, Accuracy: 100.00%
# Validation Accuracy: 46.67%
# Epoch 133/200, Loss: 0.0001, Accuracy: 100.00%
# Validation Accuracy: 46.67%
# Epoch 134/200, Loss: 0.0000, Accuracy: 100.00%
# Validation Accuracy: 48.33%
# Epoch 135/200, Loss: 0.0000, Accuracy: 100.00%
# Validation Accuracy: 45.83%
# Epoch 136/200, Loss: 0.0001, Accuracy: 100.00%
# Validation Accuracy: 46.67%
# Epoch 137/200, Loss: 0.0001, Accuracy: 100.00%
# Validation Accuracy: 44.17%
# Epoch 138/200, Loss: 0.0001, Accuracy: 100.00%
# Validation Accuracy: 46.67%
# Epoch 139/200, Loss: 0.0000, Accuracy: 100.00%
# Validation Accuracy: 45.00%
# Epoch 140/200, Loss: 0.0000, Accuracy: 100.00%
# Validation Accuracy: 47.50%
# Epoch 141/200, Loss: 0.0000, Accuracy: 100.00%
# Validation Accuracy: 47.50%
# Epoch 142/200, Loss: 0.0001, Accuracy: 100.00%
# Validation Accuracy: 48.33%
# Epoch 143/200, Loss: 0.0000, Accuracy: 100.00%
# Validation Accuracy: 45.83%
# Epoch 144/200, Loss: 0.0000, Accuracy: 100.00%
# Validation Accuracy: 47.50%
# Epoch 145/200, Loss: 0.0000, Accuracy: 100.00%
# Validation Accuracy: 45.00%
# Epoch 146/200, Loss: 0.0000, Accuracy: 100.00%
# Validation Accuracy: 47.50%
# Epoch 147/200, Loss: 0.0001, Accuracy: 100.00%
# Validation Accuracy: 48.33%
# Epoch 148/200, Loss: 0.0000, Accuracy: 100.00%
# Validation Accuracy: 50.00%
# Epoch 149/200, Loss: 0.0000, Accuracy: 100.00%
# Validation Accuracy: 47.50%
# Epoch 150/200, Loss: 0.0000, Accuracy: 100.00%
# Validation Accuracy: 48.33%
# Epoch 151/200, Loss: 0.0000, Accuracy: 100.00%
# Validation Accuracy: 47.50%
# Epoch 152/200, Loss: 0.0004, Accuracy: 100.00%
# Validation Accuracy: 45.83%
# Epoch 153/200, Loss: 0.1171, Accuracy: 97.22%
# Validation Accuracy: 48.33%
# Epoch 154/200, Loss: 0.8845, Accuracy: 69.44%
# Validation Accuracy: 44.17%
# Epoch 155/200, Loss: 0.4287, Accuracy: 84.91%
# Validation Accuracy: 54.17%
# Epoch 156/200, Loss: 0.1634, Accuracy: 94.26%
# Validation Accuracy: 43.33%
# Epoch 157/200, Loss: 0.0534, Accuracy: 98.43%
# Validation Accuracy: 45.00%
# Epoch 158/200, Loss: 0.0581, Accuracy: 98.52%
# Validation Accuracy: 40.00%
# Epoch 159/200, Loss: 0.0429, Accuracy: 99.35%
# Validation Accuracy: 44.17%
# Epoch 160/200, Loss: 0.0148, Accuracy: 99.54%
# Validation Accuracy: 44.17%
# Epoch 161/200, Loss: 0.0037, Accuracy: 100.00%
# Validation Accuracy: 47.50%
# Epoch 162/200, Loss: 0.0021, Accuracy: 100.00%
# Validation Accuracy: 46.67%
# Epoch 163/200, Loss: 0.0014, Accuracy: 100.00%
# Validation Accuracy: 46.67%
# Epoch 164/200, Loss: 0.0009, Accuracy: 100.00%
# Validation Accuracy: 45.83%
# Epoch 165/200, Loss: 0.0006, Accuracy: 100.00%
# Validation Accuracy: 48.33%
# Epoch 166/200, Loss: 0.0011, Accuracy: 100.00%
# Validation Accuracy: 46.67%
# Epoch 167/200, Loss: 0.0004, Accuracy: 100.00%
# Validation Accuracy: 48.33%
# Epoch 168/200, Loss: 0.0005, Accuracy: 100.00%
# Validation Accuracy: 46.67%
# Epoch 169/200, Loss: 0.0004, Accuracy: 100.00%
# Validation Accuracy: 45.83%
# Epoch 170/200, Loss: 0.0004, Accuracy: 100.00%
# Validation Accuracy: 46.67%
# Epoch 171/200, Loss: 0.0003, Accuracy: 100.00%
# Validation Accuracy: 46.67%
# Epoch 172/200, Loss: 0.0003, Accuracy: 100.00%
# Validation Accuracy: 45.83%
# Epoch 173/200, Loss: 0.0002, Accuracy: 100.00%
# Validation Accuracy: 46.67%
# Epoch 174/200, Loss: 0.0002, Accuracy: 100.00%
# Validation Accuracy: 45.83%
# Epoch 175/200, Loss: 0.0005, Accuracy: 100.00%
# Validation Accuracy: 45.83%
# Epoch 176/200, Loss: 0.0002, Accuracy: 100.00%
# Validation Accuracy: 45.83%
# Epoch 177/200, Loss: 0.0003, Accuracy: 100.00%
# Validation Accuracy: 45.00%
# Epoch 178/200, Loss: 0.0002, Accuracy: 100.00%
# Validation Accuracy: 46.67%
# Epoch 179/200, Loss: 0.0001, Accuracy: 100.00%
# Validation Accuracy: 45.00%
# Epoch 180/200, Loss: 0.0002, Accuracy: 100.00%
# Validation Accuracy: 45.83%
# Epoch 181/200, Loss: 0.0002, Accuracy: 100.00%
# Validation Accuracy: 44.17%
# Epoch 182/200, Loss: 0.0001, Accuracy: 100.00%
# Validation Accuracy: 45.83%
# Epoch 183/200, Loss: 0.0002, Accuracy: 100.00%
# Validation Accuracy: 46.67%
# Epoch 184/200, Loss: 0.0001, Accuracy: 100.00%
# Validation Accuracy: 46.67%
# Epoch 185/200, Loss: 0.0001, Accuracy: 100.00%
# Validation Accuracy: 45.83%
# Epoch 186/200, Loss: 0.0001, Accuracy: 100.00%
# Validation Accuracy: 45.83%
# Epoch 187/200, Loss: 0.0001, Accuracy: 100.00%
# Validation Accuracy: 45.00%
# Epoch 188/200, Loss: 0.0001, Accuracy: 100.00%
# Validation Accuracy: 45.00%
# Epoch 189/200, Loss: 0.0003, Accuracy: 100.00%
# Validation Accuracy: 46.67%
# Epoch 190/200, Loss: 0.0001, Accuracy: 100.00%
# Validation Accuracy: 45.00%
# Epoch 191/200, Loss: 0.0001, Accuracy: 100.00%
# Validation Accuracy: 45.83%
# Epoch 192/200, Loss: 0.0001, Accuracy: 100.00%
# Validation Accuracy: 45.83%
# Epoch 193/200, Loss: 0.0001, Accuracy: 100.00%
# Validation Accuracy: 45.00%
# Epoch 194/200, Loss: 0.0001, Accuracy: 100.00%
# Validation Accuracy: 46.67%
# Epoch 195/200, Loss: 0.0001, Accuracy: 100.00%
# Validation Accuracy: 47.50%
# Epoch 196/200, Loss: 0.0002, Accuracy: 100.00%
# Validation Accuracy: 46.67%
# Epoch 197/200, Loss: 0.0001, Accuracy: 100.00%
# Validation Accuracy: 45.83%
# Epoch 198/200, Loss: 0.0001, Accuracy: 100.00%
# Validation Accuracy: 46.67%
# Epoch 199/200, Loss: 0.0002, Accuracy: 100.00%
# Validation Accuracy: 46.67%
# Epoch 200/200, Loss: 0.0001, Accuracy: 100.00%
# Validation Accuracy: 48.33%

# %%
# Plot Training Accuracy
plt.figure(figsize=(10, 6))
plt.plot(range(1, num_epochs + 1), train_acc, marker='o')
plt.xlabel("Epoch")
plt.ylabel("Accuracy (%)")
plt.title("Training Accuracy per Epoch")
plt.grid()
plt.show()

# %% [markdown]
# ## Display Example Predictions

# %%
import random
import matplotlib.pyplot as plt

# Function to display random samples with predictions and actual labels
def visualize_predictions(model, dataset, num_samples=5):
    model.eval()  # Set the model to evaluation mode
    samples = random.sample(range(len(dataset)), num_samples)

    fig, axes = plt.subplots(1, num_samples, figsize=(15, 5))
    # loop over each randomly selected sample index
    for i, idx in enumerate(samples):
        image, label = dataset[idx]
        image_tensor = image.unsqueeze(0).to(device)  # Add batch dimension and move to device
        with torch.no_grad():
            output = model(image_tensor)
            predicted_label = torch.argmax(output, 1).item()

        # move the image back to CPU for visualization
        image = image.permute(1, 2, 0).cpu().numpy()
        image = (image * 0.5) + 0.5  # undo normalization for visualization
        # plot the image on the corresponding axis
        axes[i].imshow(image)
        axes[i].axis("off")
        axes[i].set_title(f"Predicted: {predicted_label}\nActual: {label}")

    plt.tight_layout()
    plt.show()

# Visualize predictions
visualize_predictions(model, val_dataset, num_samples=5)
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# ## Confusion Matrix

# %%
# plot confusion matrix
def plot_confusion_matrix(cm, class_names):
    plt.figure(figsize=(8, 6))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
    plt.title('Confusion Matrix')
    plt.xlabel('Predicted Labels')
    plt.ylabel('True Labels')
    plt.show()

# generate confusion matrix
def generate_confusion_matrix(model, dataloader):
    model.eval()  # Set the model to evaluation mode
    all_labels = []
    all_preds = []

    with torch.no_grad():  # No need to track gradients during inference
        for inputs, labels in dataloader:
            inputs, labels = inputs.to(device), labels.to(device)  # Move to device
            outputs = model(inputs)  # Forward pass
            _, predicted = torch.max(outputs, 1)  # Get predicted class
            all_labels.extend(labels.cpu().numpy())  # Store true labels
            all_preds.extend(predicted.cpu().numpy())  # Store predicted labels

    # Convert lists to numpy arrays
    all_labels = np.array(all_labels)
    all_preds = np.array(all_preds)

    # Compute confusion matrix
    cm = confusion_matrix(all_labels, all_preds)

    # Define the class names (adjust if necessary based on your dataset)
    class_names = [str(i) for i in range(5)]  # Assuming 5 classes (0 to 4)

    # Plot confusion matrix
    plot_confusion_matrix(cm, class_names)

generate_confusion_matrix(model, val_loader)

# %% [markdown]
# ## Saliency

# %%
def visualize_saliency(model, dataset, num_samples=5):
    model.eval()  # Set the model to evaluation mode
    samples = random.sample(range(len(dataset)), num_samples)  # Randomly sample from the dataset

    # Create a subplot grid (num_samples rows, 3 columns for original, saliency map, and overlay)
    fig, axes = plt.subplots(num_samples, 3, figsize=(10, 5 * num_samples))

    for i, idx in enumerate(samples):
        image, label = dataset[idx]  # Get the image and its label from the dataset
        image_tensor = image.unsqueeze(0).to(device)  # Add batch dimension and move to the device (GPU/CPU)

        image_tensor.requires_grad_()  # Enable gradient tracking for the image tensor

        # Forward pass to get model predictions
        output = model(image_tensor)  # Forward pass through the model
        predicted_label = torch.argmax(output, 1).item()  # Get the predicted class

        # Compute gradients of the output w.r.t the input image
        model.zero_grad()  # Reset gradients from the previous backward pass
        output[0, predicted_label].backward()  # Backpropagate to get the gradient for the predicted class
        saliency = image_tensor.grad.abs().squeeze().cpu().numpy()  # Get the saliency map (absolute gradient)

        # Normalize the saliency map (optional but useful for visualization)
        saliency = saliency.max(axis=0)  # Take the maximum saliency value across channels (for RGB)
        saliency = (saliency - saliency.min()) / (saliency.max() - saliency.min())  # Normalize to [0, 1]

        # Undo normalization for the original image (to bring it back to [0, 1] for display)
        image_np = image.permute(1, 2, 0).cpu().numpy()  # Convert the image to numpy (H, W, C)
        image_np = (image_np * 0.5) + 0.5  # Undo the normalization (from [-1, 1] back to [0, 1])

        # Overlay saliency map on top of the original image
        overlay = np.clip(image_np + np.expand_dims(saliency, axis=-1), 0, 1)  # Combine saliency with the image

        # Plot the original image, the saliency map, and the overlay
        axes[i, 0].imshow(image_np)
        axes[i, 0].axis("off")
        axes[i, 0].set_title("Original Image")

        axes[i, 1].imshow(saliency, cmap="hot")  # Display the saliency map with a 'hot' colormap
        axes[i, 1].axis("off")
        axes[i, 1].set_title("Saliency Map")

        axes[i, 2].imshow(overlay)  # Display the image with the saliency map overlaid
        axes[i, 2].axis("off")
        axes[i, 2].set_title(f"Predicted: {predicted_label}\nActual: {label}")

    # Adjust layout and show the plot
    plt.tight_layout()
    plt.show()

# Call the function to visualize saliency maps on the validation dataset
visualize_saliency(model, val_dataset, num_samples=5)
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
